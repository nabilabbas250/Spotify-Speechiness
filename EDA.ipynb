# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# #### SPEECH_speechy is my classifier column.
#
# 1 = speechy
# 0 = musical

# %%
df2 = pd.read_csv('df2_info.csv')
df2 = df2.set_index('id')
df2.drop(columns = 'SPEECH_musical', inplace= True)

# %%
df2.head()
# Out:
#                         acousticness  danceability  duration_ms  energy  \
# id
# 30oTS7bm0aH3p7lqjEIu8q        0.0253         0.877       216596   0.740
# 2g8HN35AnVGIk7B8yMucww        0.4320         0.778       252747   0.578
# 33ZXjLCpiINn8eQIDYEPTD        0.0146         0.763       325507   0.786
# 2qOm7ukLyHUXWyR4ZWLwxA        0.3210         0.796       260000   0.748
# 119c93MHjrDLJTApCVGpvx        0.5700         0.479       252187   0.549
#
#                         instrumentalness  liveness  loudness  speechiness  \
# id
# 30oTS7bm0aH3p7lqjEIu8q          0.000003    0.2860    -5.885        0.271
# 2g8HN35AnVGIk7B8yMucww          0.000000    0.1380    -7.220        0.274
# 33ZXjLCpiINn8eQIDYEPTD          0.011400    0.0817    -6.472        0.229
# 2qOm7ukLyHUXWyR4ZWLwxA          0.000049    0.2170    -5.409        0.126
# 119c93MHjrDLJTApCVGpvx          0.023900    0.1270   -10.551        0.373
#
# ...

# %%
sns.jointplot(x='danceability', y='speechiness', data= df2)

# %%
sns.jointplot(x='danceability', y='speechiness', data = df2, kind = "kde")

# %%
sns.pairplot(df2)

# %%
fig = plt.figure(1)

columns = 3
rows = 5

for i in range(1, columns*rows+1):
    fig.add_subplot(rows, columns, i)
    plt.scatter(x, y)

plt.tight_layout()
plt.show()

# %%
df2.columns

#acousticness, danceability, duration_ms, energy, instrumentalness
#liveness, loudness, speechiness, tempo
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'key_0', 'key_1', 'key_2', 'key_3', 'key_4', 'key_5',
#        'key_6', 'key_7', 'key_8', 'key_9', 'key_10', 'key_11', 'mode_0',
#        'mode_1', 'time_signature_0', 'time_signature_1', 'time_signature_3',
#        'time_signature_4', 'time_signature_5', 'SPEECH_speechy'],
#       dtype='object')

# %%
features = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness'
'liveness', 'loudness', 'tempo']

fig = plt.figure(1)
columns = 3
rows = 3

for i in range(1, columns*rows +1):
